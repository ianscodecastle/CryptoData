# %%
import pandas as pd
import requests
import config_demo
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pprint

# info here: https://towardsdev.com/create-an-etl-pipeline-in-python-with-pandas-in-10-minutes-6be436483ec9

pp = pprint

key = config_demo.api_key
url = config_demo.latest_quotes

parameters = {
  'slug': 'bitcoin',  
  'convert': 'USD',
}

headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY':  key,
}

session = Session()
session.headers.update(headers)


try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  pd.set_option("display.max_rows", None)
  pd.set_option("display.max_columns", None)
  df = pd.DataFrame.from_records(data)
  display(df)
  pp.pprint(df.loc['bitcoin','data'])
  #df.to_csv('cmc_dataframe.csv', index=False)

except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
#                                                             data  \
# bitcoin        {'id': 109, 'name': 'h4bdc8muecd', 'symbol': '...
# timestamp                                                    NaN
# error_code                                                   NaN
# error_message                                                NaN
# elapsed                                                      NaN
# credit_count                                                 NaN
# notice                                                       NaN
#
#                                  status
# bitcoin                             NaN
# timestamp      2022-03-23T18:03:35.253Z
# error_code                            0
# error_message                      None
# elapsed                               0
# credit_count                          1
# notice                             None
# {'circulating_supply': 2742,
#  'cmc_rank': 9115,
#  'date_added': '2022-03-23T18:03:35.253Z',
#  'id': 109,
#  'is_active': 7956,
#  'is_fiat': None,
#  'last_updated': '2022-03-23T18:03:35.253Z',
#  'max_supply': 4024,
#  'name': 'h4bdc8muecd',
#  'num_market_pairs': 3477,
#  'platform': None,
#  'quote': {'USD': {'fully_diluted_market_cap': 0.15129182226978521,
#                    'last_updated': '2022-03-23T18:03:35.253Z',
#                    'market_cap': 0.7922665310319181,
#                    'market_cap_dominance': 1487,
#                    'percent_change_1h': 0.8485061843457269,
#                    'percent_change_24h': 0.09811129811772701,
#                    'percent_change_30d': 0.40817172078047936,
#                    'percent_change_7d': 0.9944446378975553,
#                    'price': 0.48008956674678904,
#                    'volume_24h': 0.8960324163964537,
#                    'volume_change_24h': 0.9699421412281597}},
#  'self_reported_circulating_supply': None,
#  'self_reported_market_cap': None,
#  'slug': 'bitcoin',
#  'symbol': 'z2ec6nw7y2q',
#  'tags': ['bwghgujk85',
#           'm0w9tpo2asn',
#           'ch0vistub8',
#           'rpipdgqk4nb',
#           'pp65s65knqm',
#           'q4smy1hcian',
#           'fo6u614ij2g',
#           '52um2f2zkd',
#           'h0lzwrtfmlp',
#           '6fwyoouk47p'],
#  'total_supply': 9354}
