# %%
# Imports
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pandas as pd
import pprint as pp
import config


# Show latest listings
url = config.latest_quotes
parameters = {
  'slug':'bitcoin',
  'convert':'USD'
}

headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': config.sandbox_key,
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #df = pd.DataFrame.from_records(data)
  df = pd.json_normalize(data, meta=['quotes'])
  display(df)
  #pp.pprint(df.loc['bitcoin','data'])
  #df.to_csv('cmc_dataframe.csv', index=False)

except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
#            status.timestamp  status.error_code status.error_message  \
# 0  2022-03-23T22:41:31.039Z                  0                 None
#
#    status.elapsed  status.credit_count status.notice  data.bitcoin.id  \
# 0               1                    1          None             1245
#
#   data.bitcoin.name data.bitcoin.symbol data.bitcoin.slug  ...  \
# 0        qci6avvaf9         1obj3x6d29h           bitcoin  ...
#
#    data.bitcoin.quote.USD.volume_24h data.bitcoin.quote.USD.volume_change_24h  \
# 0                           0.924774                                 0.744433
#
#    data.bitcoin.quote.USD.percent_change_1h  \
# 0                                  0.003648
#
#    data.bitcoin.quote.USD.percent_change_24h  \
# 0                                   0.450356
#
#    data.bitcoin.quote.USD.percent_change_7d  \
# 0                                  0.261388
#
#   data.bitcoin.quote.USD.percent_change_30d  \
# 0                                  0.140351
#
#    data.bitcoin.quote.USD.market_cap  \
# 0                           0.479893
#
#    data.bitcoin.quote.USD.market_cap_dominance  \
# 0                                         8154
#
#   data.bitcoin.quote.USD.fully_diluted_market_cap  \
# 0                                        0.097147
#
#   data.bitcoin.quote.USD.last_updated
# 0            2022-03-23T22:41:31.039Z
#
# [1 rows x 34 columns]
