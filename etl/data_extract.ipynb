# %%
# Imports
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pandas as pd
import pprint as pp
import config

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 50)

# Show latest listings
url = config.latest_quotes
parameters = {
  'slug':'bitcoin,ethereum,chainlink,polkadot,cardano',
  #'convert':'USD'
}

headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': config.sandbox_key,
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  
  # Specify which data from API response to store
  data = json.loads(response.text)['data']

  # Make data frame
  df = pd.DataFrame(data).T
  df = pd.json_normalize(list(data.values()))
  #df.index = data.keys()

  # Display dataframe
  display(df)

  # Load to destination
  #df.to_csv('cmc_dataframe.csv', index=False)

except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
#      id         name       symbol       slug  is_active is_fiat  \
# 0  4592   j09uae86y5  9p2o6zmgvmk    bitcoin       5487    None
# 1  5610  tv5d8vpgonr  9700gbmjcps    cardano       7303    None
# 2  9854  yp1t0wkl8in  a1nt404v80v  chainlink       8989    None
# 3  7971  akjqq6zmkte  2z7nmod5jbm   ethereum       2404    None
# 4  7520  e4na137k3pn  1zn2nidu0sj   polkadot       9947    None
#
#    circulating_supply  total_supply  max_supply                date_added  \
# 0                2689          4074         427  2022-03-23T23:35:41.208Z
# 1                7393          7455        2682  2022-03-23T23:35:41.208Z
# 2                 379          4939        7940  2022-03-23T23:35:41.208Z
# 3                4140            76        9394  2022-03-23T23:35:41.208Z
# 4                8532          6171        9794  2022-03-23T23:35:41.208Z
#
#    num_market_pairs  cmc_rank              last_updated  \
# 0              1654      7194  2022-03-23T23:35:41.208Z
# 1              7280      1371  2022-03-23T23:35:41.208Z
# 2              5759       725  2022-03-23T23:35:41.208Z
# 3              9355      7489  2022-03-23T23:35:41.208Z
# 4              4653      5521  2022-03-23T23:35:41.208Z
#
#                                                 tags platform  \
# 0  [mcdjzmvit6l, t1typcuccdg, ml98qy7ywf8, x124l2...     None
# 1  [fo5m8gw8w5w, 8e8z3lncsy6, dkmg2q3cmau, d0lx6n...     None
# 2  [iw7yaycbukb, le6uthwo269, n94mlmlu4q, ijuv6as...     None
# 3  [k5jsj4pd1ul, bdkpib52wf, somy6haifig, gp9597p...     None
# 4  [wpwcze04hk, e8h7ay19hoi, bl1ve3n96an, 3yix61b...     None
#
#   self_reported_circulating_supply self_reported_market_cap  quote.USD.price  \
# 0                             None                     None         0.341296
# 1                             None                     None         0.574434
# 2                             None                     None         0.020384
# 3                             None                     None         0.334764
# 4                             None                     None         0.885790
#
#    quote.USD.volume_24h  quote.USD.volume_change_24h  \
# 0              0.538088                     0.059310
# 1              0.295916                     0.161998
# 2              0.100729                     0.629500
# 3              0.730955                     0.858934
# 4              0.781567                     0.940512
#
#    quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# 0                     0.939739                      0.615745
# 1                     0.448990                      0.695124
# 2                     0.952154                      0.860383
# 3                     0.047908                      0.686425
# 4                     0.712383                      0.067158
#
#    quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# 0                     0.807631                      0.678717
# 1                     0.074192                      0.452071
# 2                     0.273014                      0.892018
# 3                     0.157736                      0.013512
# 4                     0.041065                      0.759063
#
#    quote.USD.market_cap  quote.USD.market_cap_dominance  \
# 0              0.075951                            8865
# 1              0.700684                            7882
# 2              0.842591                            1589
# 3              0.596688                            8357
# 4              0.703806                             590
#
#    quote.USD.fully_diluted_market_cap    quote.USD.last_updated
# 0                            0.004891  2022-03-23T23:35:41.208Z
# 1                            0.285879  2022-03-23T23:35:41.208Z
# 2                            0.873804  2022-03-23T23:35:41.208Z
# 3                            0.025019  2022-03-23T23:35:41.208Z
# 4                            0.732319  2022-03-23T23:35:41.208Z
